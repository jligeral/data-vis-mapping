# %%
import pandas as pd

# %% [markdown]
# ## Import Data
#
# Save the data in a seperate directory, then read from its path below

# %%
df = pd.read_csv(
    "../data/raw/works-2025-11-18T01-33-45.csv",
    dtype=str,
    low_memory=False,
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45554 entries, 0 to 45553
# Columns: 187 entries, id to institutions.lineage
# dtypes: object(187)
# memory usage: 65.0+ MB

# %%
df.columns
# Out:
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'language', 'type', 'indexed_in',
#        'countries_distinct_count',
#        ...
#        'funders.display_name', 'funders.ror', 'counts_by_year.year',
#        'counts_by_year.cited_by_count', 'institutions.id',
#        'institutions.display_name', 'institutions.ror',
#        'institutions.country_code', 'institutions.type',
#        'institutions.lineage'],
#       dtype='object', length=187)

# %%
df.describe()
# Out:
#                                       id                           doi  \
# count                              45554                         35611
# unique                             45554                         35598
# top     https://openalex.org/W2028056984  https://doi.org/10.2788/1823
# freq                                   1                             2
#
#                                title                  display_name  \
# count                          45544                         45544
# unique                         44422                         44422
# top     TVCG Information for authors  TVCG Information for authors
# freq                              26                            26
#
#        publication_year publication_date language     type indexed_in  \
# count             45534            45534    45422    45554      34714
# unique               59             6507       38        1         24
# ...

# %%
df.head(10)
# Out:
#                                  id  \
# 0  https://openalex.org/W2028056984
# 1  https://openalex.org/W2056279562
# 2  https://openalex.org/W2128880918
# 3  https://openalex.org/W2114843025
# 4  https://openalex.org/W2047968138
# 5  https://openalex.org/W3036319615
# 6  https://openalex.org/W2158804744
# 7  https://openalex.org/W2117131162
# 8  https://openalex.org/W2800392236
# 9  https://openalex.org/W2155806125
#
#                                              doi  \
# 0      https://doi.org/10.1107/s0021889811038970
# 1   https://doi.org/10.1371/journal.pone.0061217
# 2  https://doi.org/10.1093/bioinformatics/bts199
# 3      https://doi.org/10.1126/scisignal.2004088
# 4  https://doi.org/10.1088/0965-0393/18/1/015012
# 5     https://doi.org/10.1016/j.molp.2020.06.009
# 6          https://doi.org/10.1101/gr.092759.109
# 7             https://doi.org/10.1093/bib/bbs017
# 8      https://doi.org/10.1186/s13059-017-1382-0
# 9             https://doi.org/10.1093/nar/gkh293
#
# ...

# %%
for i, col in enumerate(df.columns):
    print(i, col)
# Out:
# 0 id
# 1 doi
# 2 title
# 3 display_name
# 4 publication_year
# 5 publication_date
# 6 language
# 7 type
# 8 indexed_in
# 9 countries_distinct_count
# 10 institutions_distinct_count
# 11 corresponding_author_ids
# 12 corresponding_institution_ids
# 13 apc_paid
# 14 fwci
# 15 cited_by_count
# 16 is_retracted
# 17 is_paratext
# 18 is_xpac
# 19 locations_count
# 20 best_oa_location
# 21 awards
# 22 referenced_works_count
# 23 referenced_works
# 24 related_works
# 25 updated_date
# 26 created_date
# 27 ids.openalex
# 28 ids.doi
# 29 ids.mag
# 30 primary_location.id
# 31 primary_location.is_oa
# 32 primary_location.landing_page_url
# 33 primary_location.pdf_url
# 34 primary_location.source.id
# 35 primary_location.source.display_name
# 36 primary_location.source.issn_l
# 37 primary_location.source.issn
# 38 primary_location.source.is_oa
# 39 primary_location.source.is_in_doaj
# 40 primary_location.source.is_core
# 41 primary_location.source.host_organization
# ...

# %% [markdown]
# ## Columns to keep
# id, title, publication_year, cited_by_count
#
# I need to examine a few other columns first including primary_location.source.host_organization, abstract, primary_topic, authorships.author.display_name, topics.display_name, keywords.display_name

# %%
df[["concepts.display_name", "topics.display_name", "authorships.author.display_name", "primary_location.source.host_organization_name"]].head(10)
# Out:
#                                concepts.display_name  \
# 0  Undo|Visualization|Voronoi diagram|Computer sc...
# 1  UniFrac|Computer science|Data science|Data min...
# 2  Computer science|Software|Personalization|Leve...
# 3  Genomics|Visualization|Interface (matter)|Comp...
# 4  Visualization|Python (programming language)|Sc...
# 5  Computer science|Software|Java|Big data|Visual...
# 6  Biology|Genome|Visualization|Computational bio...
# 7  Visualization|Computer science|Data visualizat...
# 8  Python (programming language)|Preprocessor|Inf...
# 9  Biology|Sequence database|Phylogenetic tree|Vi...
#
#                                  topics.display_name  \
# 0  Catalysis and Oxidation Reactions|X-ray Diffra...
# 1  Species Distribution and Climate Change|Data A...
# 2  Scientific Computing and Data Management|Genom...
# 3  Bioinformatics and Genomic Networks|Cancer Gen...
# 4  Theoretical and Computational Physics|Machine ...
# 5  Genomics and Phylogenetic Studies|Bioinformati...
# ...

# %% [markdown]
# I've decided that the queried columns above are good to keep, so I'll slim down the dataset

# %%
keep_cols = [
    "id",
    "title",
    "publication_year",
    "authorships.author.display_name",
    "concepts.display_name",
    "topics.display_name",
    "primary_location.source.host_organization_name",
    "cited_by_count",
    "abstract"
]

# %%
df_small = df[keep_cols].copy()

# %%
df_small.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2028056984
# 1  https://openalex.org/W2056279562
# 2  https://openalex.org/W2128880918
# 3  https://openalex.org/W2114843025
# 4  https://openalex.org/W2047968138
#
#                                                title publication_year  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...           2011.0
# 1  phyloseq: An R Package for Reproducible Intera...           2013.0
# 2  Geneious Basic: An integrated and extendable d...           2012.0
# 3  Integrative Analysis of Complex Cancer Genomic...           2013.0
# 4  Visualization and analysis of atomistic simula...           2009.0
#
#                      authorships.author.display_name  \
# 0                           Koichi Momma|Fujio Izumi
# 1                      Paul J. McMurdie|Susan Holmes
# 2  Matthew D. Kearse|Richard Moir|Amy Wilson|Stev...
# 3  Jianjiong Gao|Bülent Arman Aksoy|Uğur Doğrusöz...
# ...

# %%
df_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45554 entries, 0 to 45553
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              45554 non-null  object
#  1   title                                           45544 non-null  object
#  2   publication_year                                45534 non-null  object
#  3   authorships.author.display_name                 45096 non-null  object
#  4   concepts.display_name                           45554 non-null  object
#  5   topics.display_name                             45174 non-null  object
#  6   primary_location.source.host_organization_name  18225 non-null  object
#  7   cited_by_count                                  45554 non-null  object
#  8   abstract                                        11024 non-null  object
# dtypes: object(9)
# ...

# %% [markdown]
# ## Export
#
# Make the smaller dataset with relevant columns

# %%
df_small.to_csv("../data/interim/openalex_pruned.csv", index=False)
