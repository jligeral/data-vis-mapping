# %%
import pandas as pd

df = pd.read_csv("../data/interim/openalex_pruned.csv", dtype=str, low_memory=False)

# %% [markdown]
# ## Small note
#
# Some rows do not contain abstracts, thus we can either ignore them or substitute them. In this case, I will substitute them with other metadata. Additionally, some titles and publication years are missing, so I'll completely remove those entries.

# %%
df = df.dropna(subset=["title", "publication_year"], how="any")

# %%
df["abstract"].isna().sum(), len(df)
# Out:
# (34515, 45532)

# %% [markdown]
# So it looks like roughly 10K entries lack an abstract. I'll fill the missing entries below with the title since some titles are descriptive enough to describe the contents of the articles.

# %%
df["text"] = df["abstract"].fillna(df["title"])

# %% [markdown]
# Below simply checks if any titles are missing. If the list is empty, then we're good.

# %%
df[df["text"].isna()]
# Out:
# Empty DataFrame
# Columns: [id, title, publication_year, authorships.author.display_name, concepts.display_name, topics.display_name, primary_location.source.host_organization_name, cited_by_count, abstract, text]
# Index: []

# %% [markdown]
# ## Vectorization
#
# Below I create the embeddings using TD-IDF so that I can use them later for a dimensional reduction.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=50000,
    max_df=0.3,
    min_df=10
)

tfidf = vectorizer.fit_transform(df["text"])
tfidf
# Out:
# <45532x7455 sparse matrix of type '<class 'numpy.float64'>'
# 	with 927557 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Dimensional Reduction with UMAP

# %%
import umap

umap_3d = umap.UMAP(
    n_components=3,
    n_neighbors=30,
    min_dist=0.0,
    metric='cosine',
    random_state=42
)

embedding_3d = umap_3d.fit_transform(tfidf)
# Out:
# /Users/blues/Library/Python/3.9/lib/python/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
df["x"] = embedding_3d[:, 0]
df["y"] = embedding_3d[:, 1]
df["z"] = embedding_3d[:, 2]

# %% [markdown]
# ## Clustering
#
# We can group the above embedding based on how close they are below

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(
    min_cluster_size=50,
    metric='euclidean',
    cluster_selection_method='eom'
)

labels = clusterer.fit_predict(embedding_3d)
df["cluster"] = labels
# Out:
# /Users/blues/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/blues/Library/Python/3.9/lib/python/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# ## Final inspection and export
#
# Check the metadata we want and export it out

# %%
df.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2028056984
# 1  https://openalex.org/W2056279562
# 2  https://openalex.org/W2128880918
# 3  https://openalex.org/W2114843025
# 4  https://openalex.org/W2047968138
#
#                                                title publication_year  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...           2011.0
# 1  phyloseq: An R Package for Reproducible Intera...           2013.0
# 2  Geneious Basic: An integrated and extendable d...           2012.0
# 3  Integrative Analysis of Complex Cancer Genomic...           2013.0
# 4  Visualization and analysis of atomistic simula...           2009.0
#
#                      authorships.author.display_name  \
# 0                           Koichi Momma|Fujio Izumi
# 1                      Paul J. McMurdie|Susan Holmes
# 2  Matthew D. Kearse|Richard Moir|Amy Wilson|Stev...
# 3  Jianjiong Gao|Bülent Arman Aksoy|Uğur Doğrusöz...
# 4                                Alexander Stukowski
#
#                                concepts.display_name  \
# 0  Undo|Visualization|Voronoi diagram|Computer sc...
# 1  UniFrac|Computer science|Data science|Data min...
# 2  Computer science|Software|Personalization|Leve...
# 3  Genomics|Visualization|Interface (matter)|Comp...
# 4  Visualization|Python (programming language)|Sc...
#
#                                  topics.display_name  \
# 0  Catalysis and Oxidation Reactions|X-ray Diffra...
# 1  Species Distribution and Climate Change|Data A...
# 2  Scientific Computing and Data Management|Genom...
# 3  Bioinformatics and Genomic Networks|Cancer Gen...
# 4  Theoretical and Computational Physics|Machine ...
#
#       primary_location.source.host_organization_name cited_by_count  \
# 0                                              Wiley          22839
# 1                          Public Library of Science          20085
# 2                            Oxford University Press          19717
# 3  American Association for the Advancement of Sc...          15249
# 4                                     IOP Publishing          14576
#
#                                             abstract  \
# 0                                                NaN
# 1  The phyloseq project for R is a new open-sourc...
# 2  Abstract Summary: The two main functions of bi...
# 3  The cBioPortal enables integration, visualizat...
# 4                                                NaN
#
#                                                 text          x          y  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...   9.508135  12.053864
# 1  The phyloseq project for R is a new open-sourc...  11.787406  11.985596
# 2  Abstract Summary: The two main functions of bi...  11.948407  12.137466
# 3  The cBioPortal enables integration, visualizat...  11.768088  12.328234
# 4  Visualization and analysis of atomistic simula...   9.105033  11.859065
#
#           z  cluster
# 0 -0.384366      110
# 1 -0.692306       -1
# 2 -0.855199       -1
# 3 -1.023483       47
# 4 -0.284749       -1

# %% [markdown]
# ## Checking final dataset
#
# Below should give a quick run-down of what's in the dataset

# %%
df_out.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2028056984
# 1  https://openalex.org/W2056279562
# 2  https://openalex.org/W2128880918
# 3  https://openalex.org/W2114843025
# 4  https://openalex.org/W2047968138
#
#                                                title publication_year  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...           2011.0
# 1  phyloseq: An R Package for Reproducible Intera...           2013.0
# 2  Geneious Basic: An integrated and extendable d...           2012.0
# 3  Integrative Analysis of Complex Cancer Genomic...           2013.0
# 4  Visualization and analysis of atomistic simula...           2009.0
#
#                                          authorships  \
# 0                           Koichi Momma|Fujio Izumi
# 1                      Paul J. McMurdie|Susan Holmes
# 2  Matthew D. Kearse|Richard Moir|Amy Wilson|Stev...
# 3  Jianjiong Gao|Bülent Arman Aksoy|Uğur Doğrusöz...
# 4                                Alexander Stukowski
#
#                                             concepts  \
# 0  Undo|Visualization|Voronoi diagram|Computer sc...
# 1  UniFrac|Computer science|Data science|Data min...
# 2  Computer science|Software|Personalization|Leve...
# 3  Genomics|Visualization|Interface (matter)|Comp...
# 4  Visualization|Python (programming language)|Sc...
#
#                                               topics  \
# 0  Catalysis and Oxidation Reactions|X-ray Diffra...
# 1  Species Distribution and Climate Change|Data A...
# 2  Scientific Computing and Data Management|Genom...
# 3  Bioinformatics and Genomic Networks|Cancer Gen...
# 4  Theoretical and Computational Physics|Machine ...
#
#                                    host_organization cited_by_count  \
# 0                                              Wiley          22839
# 1                          Public Library of Science          20085
# 2                            Oxford University Press          19717
# 3  American Association for the Advancement of Sc...          15249
# 4                                     IOP Publishing          14576
#
#                                             abstract  \
# 0                                                NaN
# 1  The phyloseq project for R is a new open-sourc...
# 2  Abstract Summary: The two main functions of bi...
# 3  The cBioPortal enables integration, visualizat...
# 4                                                NaN
#
#                                                 text          x          y  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...   9.508135  12.053864
# 1  The phyloseq project for R is a new open-sourc...  11.787406  11.985596
# 2  Abstract Summary: The two main functions of bi...  11.948407  12.137466
# 3  The cBioPortal enables integration, visualizat...  11.768088  12.328234
# 4  Visualization and analysis of atomistic simula...   9.105033  11.859065
#
#           z  cluster
# 0 -0.384366      110
# 1 -0.692306       -1
# 2 -0.855199       -1
# 3 -1.023483       47
# 4 -0.284749       -1

# %%
df_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45532 entries, 0 to 45553
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              45532 non-null  object
#  1   title                                           45532 non-null  object
#  2   publication_year                                45532 non-null  object
#  3   authorships.author.display_name                 45075 non-null  object
#  4   concepts.display_name                           45532 non-null  object
#  5   topics.display_name                             45153 non-null  object
#  6   primary_location.source.host_organization_name  18207 non-null  object
#  7   cited_by_count                                  45532 non-null  object
#  8   text                                            45532 non-null  object
#  9   x                                               45532 non-null  float32
#  10  y                                               45532 non-null  float32
#  11  z                                               45532 non-null  float32
#  12  cluster                                         45532 non-null  int64
# dtypes: float32(3), int64(1), object(9)
# memory usage: 5.4+ MB

# %% [markdown]
# Simply because I don't like the column names, I'll rename them below

# %%
new_column_names = {
    'id': 'id',
    'title': 'title',
    'publication_year': 'publication_year',
    'authorships.author.display_name': 'authorships',
    'concepts.display_name': 'concepts',
    'topics.display_name': 'topics',
    'primary_location.source.host_organization_name': 'host_organization',
    'cited_by_count': 'cited_by_count',
    'text': 'text',
}

df_out = df.rename(columns=new_column_names)

# %%
df_out.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2028056984
# 1  https://openalex.org/W2056279562
# 2  https://openalex.org/W2128880918
# 3  https://openalex.org/W2114843025
# 4  https://openalex.org/W2047968138
#
#                                                title publication_year  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...           2011.0
# 1  phyloseq: An R Package for Reproducible Intera...           2013.0
# 2  Geneious Basic: An integrated and extendable d...           2012.0
# 3  Integrative Analysis of Complex Cancer Genomic...           2013.0
# 4  Visualization and analysis of atomistic simula...           2009.0
#
#                                          authorships  \
# 0                           Koichi Momma|Fujio Izumi
# 1                      Paul J. McMurdie|Susan Holmes
# 2  Matthew D. Kearse|Richard Moir|Amy Wilson|Stev...
# 3  Jianjiong Gao|Bülent Arman Aksoy|Uğur Doğrusöz...
# 4                                Alexander Stukowski
#
#                                             concepts  \
# 0  Undo|Visualization|Voronoi diagram|Computer sc...
# 1  UniFrac|Computer science|Data science|Data min...
# 2  Computer science|Software|Personalization|Leve...
# 3  Genomics|Visualization|Interface (matter)|Comp...
# 4  Visualization|Python (programming language)|Sc...
#
#                                               topics  \
# 0  Catalysis and Oxidation Reactions|X-ray Diffra...
# 1  Species Distribution and Climate Change|Data A...
# 2  Scientific Computing and Data Management|Genom...
# 3  Bioinformatics and Genomic Networks|Cancer Gen...
# 4  Theoretical and Computational Physics|Machine ...
#
#                                    host_organization cited_by_count  \
# 0                                              Wiley          22839
# 1                          Public Library of Science          20085
# 2                            Oxford University Press          19717
# 3  American Association for the Advancement of Sc...          15249
# 4                                     IOP Publishing          14576
#
#                                             abstract  \
# 0                                                NaN
# 1  The phyloseq project for R is a new open-sourc...
# 2  Abstract Summary: The two main functions of bi...
# 3  The cBioPortal enables integration, visualizat...
# 4                                                NaN
#
#                                                 text          x          y  \
# 0  <i>VESTA 3</i>for three-dimensional visualizat...   9.508135  12.053864
# 1  The phyloseq project for R is a new open-sourc...  11.787406  11.985596
# 2  Abstract Summary: The two main functions of bi...  11.948407  12.137466
# 3  The cBioPortal enables integration, visualizat...  11.768088  12.328234
# 4  Visualization and analysis of atomistic simula...   9.105033  11.859065
#
#           z  cluster
# 0 -0.384366      110
# 1 -0.692306       -1
# 2 -0.855199       -1
# 3 -1.023483       47
# 4 -0.284749       -1

# %% [markdown]
# ## Export

# %%
df_out = df[[
    "id", "title", "publication_year",
    "authorships", "concepts", "topics", "host_organization", "cited_by_count", "text",
    "x", "y", "z", "cluster"
]]

df_out.to_json("../data/processed/topics_3d.json",
               orient="records",
               force_ascii=False)
